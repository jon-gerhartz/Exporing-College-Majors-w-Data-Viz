# %% [markdown]
# # Recent Grads Analysis Project

# %% [markdown]
# In this project, I explored job outcomes of college graduates from 2010-2012. Each row in the dataset represents a different college major. Columns in the dataset contain information on gender diversity, employment rates, and median salaries. Some initial questions I will explore include: Do certain majors make more money than others? Are certain majors predominantly male or female? What majors are the most popular?

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
recent_grads=pd.read_csv('recent-grads.csv')

# %%
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 168    Biology & Life Science    0.637293           47      6259
# 169  Psychology & Social Work    0.817099            7      2125
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 168      ...             2190                  3602         304
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
raw_data_count=recent_grads.count
raw_data_count
# Out:
# <bound method DataFrame.count of      Rank  Major_code                                          Major  \
# 0       1        2419                          PETROLEUM ENGINEERING
# 1       2        2416                 MINING AND MINERAL ENGINEERING
# 2       3        2415                      METALLURGICAL ENGINEERING
# 3       4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4       5        2405                           CHEMICAL ENGINEERING
# 5       6        2418                            NUCLEAR ENGINEERING
# 6       7        6202                              ACTUARIAL SCIENCE
# 7       8        5001                     ASTRONOMY AND ASTROPHYSICS
# 8       9        2414                         MECHANICAL ENGINEERING
# 9      10        2408                         ELECTRICAL ENGINEERING
# 10     11        2407                           COMPUTER ENGINEERING
# 11     12        2401                          AEROSPACE ENGINEERING
# ...

# %%
recent_grads.dropna(inplace=True)

# %%
cleaned_data_count=recent_grads.count
cleaned_data_count
# Out:
# <bound method DataFrame.count of      Rank  Major_code                                          Major  \
# 0       1        2419                          PETROLEUM ENGINEERING
# 1       2        2416                 MINING AND MINERAL ENGINEERING
# 2       3        2415                      METALLURGICAL ENGINEERING
# 3       4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4       5        2405                           CHEMICAL ENGINEERING
# 5       6        2418                            NUCLEAR ENGINEERING
# 6       7        6202                              ACTUARIAL SCIENCE
# 7       8        5001                     ASTRONOMY AND ASTROPHYSICS
# 8       9        2414                         MECHANICAL ENGINEERING
# 9      10        2408                         ELECTRICAL ENGINEERING
# 10     11        2407                           COMPUTER ENGINEERING
# 11     12        2401                          AEROSPACE ENGINEERING
# ...

# %% [markdown]
# # Exploring Initial Questions with Scatter Plots

# %%
ax1=recent_grads.plot(x='Sample_size', y='Median', kind='scatter')
ax1.set_title('Median Salary vs Sample Size')
# Out:
# Text(0.5, 1.0, 'Median Salary vs Sample Size')

# %% [markdown]
# This scatter plot explores the relationship between major popularity and median income. We a week correlation between the two variables. Majors with a similar sample size have a wide range of median salaries. Additionally, majors with different sample sizes have the same salaries. This suggest students are not choosing majors based on expected salary.

# %%
ax2=recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter')
ax2.set_title('Unemployment Rate vs Sample Size')
# Out:
# Text(0.5, 1.0, 'Unemployment Rate vs Sample Size')

# %% [markdown]
# There is a week relationship between unemployment rate and sample size. Low sample sizes have a large range of values for unemployment rate. Higher sample sizes have a smaller range of values but this might be because there are not enough values with a large sample size to represent the same variation as the smaller sample sizes.

# %%
ax3=recent_grads.plot(x='Full_time', y='Median', kind='scatter')
ax3.set_title('Median Salary vs Full Time')
# Out:
# Text(0.5, 1.0, 'Median Salary vs Full Time')

# %% [markdown]
# There is a weak nagative relationship between the number of full time employees and the median salary. As the number of full time employees increases, the median salary slightly decreases. There is a large variation for the majors with a small amount of full time workers. Variation decreases as the number of full time workers increases.

# %%
ax4=recent_grads.plot(x='ShareWomen', y='Unemployment_rate',kind='scatter')
ax4.set_title('Unemployment Rate vs % of Women')
# Out:
# Text(0.5, 1.0, 'Unemployment Rate vs % of Women')

# %% [markdown]
# There is no obvious relationship that can be observed from the visualization of the share of women in a major and the unemployment rate of that major. We can observe that most of the unemployment rates lie between .025 and .125.

# %%
ax5=recent_grads.plot(x='Men', y='Median',kind='scatter')
ax5.set_title('Median Salary vs Men')
# Out:
# Text(0.5, 1.0, 'Median Salary vs Men')

# %% [markdown]
# There is no obvious relationship between the number of men in the major and the median salary.

# %%
ax6=recent_grads.plot(x='Women',y='Median', kind='scatter')
ax6.set_title('Median Salary vs Women')
# Out:
# Text(0.5, 1.0, 'Median Salary vs Women')

# %% [markdown]
# There is no obvious relationshp between the number of women in a major and the median salary.

# %% [markdown]
# ## Summary of intial question visualizations

# %% [markdown]
# A common problem with this initial visualization is that many of the values for sample size, the number of full time workers, and the number of men and women are much smaller than the range represented in the visualization. Because of the large range of the visualization, it is hard to see how small differences in the number of men, women, or full time employees in a major affect the median salary. If we take a small portions of the distribution that is closer to the mean we might be able to observe stronger relationships between these variables and median salary. A few outliers are making these visualizations less useful.

# %% [markdown]
# # Exploring the Distribution of Columns with Histograms

# %%
hist1=recent_grads['Sample_size'].hist(bins=25, range=(0,5000))
hist1.set_title('Distibution of Sample Size')
# Out:
# Text(0.5, 1.0, 'Distibution of Sample Size')

# %% [markdown]
# Most of the majors in the dataset have less than 1000 people full time

# %%
hist2=recent_grads['Median'].hist(bins=25, range=(0,110000))
hist2.set_title('Distribution of Median Salaries')
# Out:
# Text(0.5, 1.0, 'Distribution of Median Salaries')

# %% [markdown]
# The most common median salary range is approximately 32000-34000

# %%
hist3=recent_grads['Employed'].hist(bins=20, range=(0,310000))
hist3.set_title('Distribution of Employed')
# Out:
# Text(0.5, 1.0, 'Distribution of Employed')

# %%
hist4=recent_grads['Full_time'].hist(bins=20, range=(0,310000))
hist4.set_title('Distribution of Full Time')
# Out:
# Text(0.5, 1.0, 'Distribution of Full Time')

# %%
hist5=recent_grads['ShareWomen'].hist(bins=20, range=(0,1))
hist5.set_title('Distribution of the Share of Women in Major')
# Out:
# Text(0.5, 1.0, 'Distribution of the Share of Women in Major')

# %% [markdown]
# Based on this histogram 95 majors or approximately 55.6% of the majors in the sample have greater than a 50% share of women. That leaves 44.4% of majors in the sample that are male dominated (have less than a 50% share of women).

# %%
hist6=recent_grads['Unemployment_rate'].hist(bins=20, range=(0,.2))
hist6.set_title('Distribution of the Unemployement Rate')
# Out:
# Text(0.5, 1.0, 'Distribution of the Unemployement Rate')

# %%
hist7=recent_grads['Men'].hist(bins=20, range=(0,174000))
hist7.set_title('Distribution of the number of Men in the major')
# Out:
# Text(0.5, 1.0, 'Distribution of the number of Men in the major')

# %%
hist8=recent_grads['Women'].hist(bins=20, range=(0,310000))
hist8.set_title('Distribution of the number of Women in the major')
# Out:
# Text(0.5, 1.0, 'Distribution of the number of Women in the major')

# %% [markdown]
# # Using Scatter Matrices to Visualize Data

# %%
from pandas.plotting import scatter_matrix
scat1=scatter_matrix(recent_grads[['Sample_size','Median']],figsize=(10,10))
scat2=scatter_matrix(recent_grads[['Sample_size','Median','Unemployment_rate']])

# %% [markdown]
# # Exploring Data with Bar Plots

# %% [markdown]
# ## Share of Women in top ranking majors verses share of women in low ranking majors

# %%
women_first=recent_grads.head(10).plot.bar(x='Major',y='ShareWomen')
women_last=recent_grads.tail(10).plot.bar(x='Major',y='ShareWomen')

# %% [markdown]
# Based on these two charts we see that there is a much larger share of women in the 10 lowest ranking majors than there are in the 10 highest ranking majors. This may indicate a larger pattern in the data that there are a larger share of women in the lower ranking or lower salary majors. We can look at a scatter plot of rank and women to see if this pattern exists throughout the dataset.

# %%
women_plot=recent_grads.plot(x='Rank',y='ShareWomen',kind='scatter')
women_plot.set_title('Major Rank vs Share of Women in Major')
# Out:
# Text(0.5, 1.0, 'Major Rank vs Share of Women in Major')

# %% [markdown]
# After running a scatter plot, we see that there is a positive correlation between rank and the share of women. As rank increases(or median salary decreases) the share of women in that major also increases. Even though we observed above that 55% of the majors were dominated by women, we could infer that most of those majors were lower paying jobs.

# %% [markdown]
# ## Unemployment Rate in Top Ranking Majors versus Unemployment Rate in Lowest Ranking Majors

# %%
unem_top=recent_grads.head(10).plot.bar(x='Major',y='Unemployment_rate')
unem_low=recent_grads.tail(10).plot.bar(x='Major',y='Unemployment_rate')

# %% [markdown]
# Althought not as strong as the share women category, we can see a higher unemployment rate for the lowest ranking majors than for the top ranking majors. We will further explore this relationship with a scatter plot below.

# %%
rank_unem=recent_grads.plot(x='Rank',y='Unemployment_rate',kind='scatter')
rank_unem.set_title('Major Rank vs Unemployment Rate')
# Out:
# Text(0.5, 1.0, 'Major Rank vs Unemployment Rate')

# %% [markdown]
# Despite the pattern discovered below between the top ranking majors and unemployment rates the lowest ranking majors and unemployment rates, the same pattern does not really exist throughout the entirety of the dataset. I would assume that the umemployment rate is more strongly correlated to the market than the majors ranking by median salary.
